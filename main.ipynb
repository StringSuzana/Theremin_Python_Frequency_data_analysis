# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

path = os.getcwd()
csv_files = glob.glob(os.path.join(path + '\Theremin Measurements', "*.csv"))

for f in csv_files:
    file_name = f.split("\\")[-1]
    print('File Name:',file_name )
    df = pd.read_csv(f)
    pd.set_option('display.max_rows', df.shape[0]+1)
    df.columns = ['Freq', 'Count', 'TIM']
    df.drop('TIM', inplace=True, axis=1)
    df['Freq'] = df['Freq'].round(1)
    print('Content:')
    print(df.head(20))
    print('\nMean of all rows: ')
    print(df.mean(axis=0))
    print('\nMedian of all rows:')
    print(df.median(axis=0))

    group_size = 10
    print(f'\nAverage per {group_size} rows [mean_table]')
    mean_table = df.groupby(np.arange(len(df))//group_size).mean()
    print(mean_table.head(5))

    #df['Freq'].plot.box(title=f"{file_name}",grid=True,figsize=(12, 5), rot=80, logy=True)
    ax = sns.countplot(x="Freq", data=df).set(title=f"{file_name}")
    plt.show()
    bin_size = 10
    df['freq_bins'] = pd.cut(df['Freq'],bin_size)
#print(df)
#print(f'\nHistogram with 2 bins ')
#print(df.hist(bins=2,  alpha=0.5,))
# Out:
# File Name: 10kHz stabilni.csv
# Content:
#        Freq   Count
# 0   10000.0  7200.0
# 1   10000.0  7200.0
# 2    9998.6  7201.0
# 3   10000.0  7200.0
# 4   10000.0  7200.0
# 5   10000.0  7200.0
# 6   10000.0  7200.0
# 7   10000.0  7200.0
# 8   10000.0  7200.0
# 9   10000.0  7200.0
# 10  10000.0  7200.0
# 11  10000.0  7200.0
# 12   9998.6  7201.0
# 13  10000.0  7200.0
# 14  10000.0  7200.0
# 15  10000.0  7200.0
# 16  10000.0  7200.0
# 17   9998.6  7201.0
# 18  10000.0  7200.0
# 19  10000.0  7200.0
#
# Mean of all rows:
# Freq     9996.540650
# Count    7200.150235
# dtype: float64
#
# Median of all rows:
# Freq     10000.0
# Count     7200.0
# dtype: float64
#
# Average per 10 rows [mean_table]
#       Freq   Count
# 0  9999.86  7200.1
# 1  9999.72  7200.2
# 2  9999.58  7200.3
# 3  9999.86  7200.1
# 4  9999.86  7200.1
# File Name: 12cm.csv
# Content:
#        Freq  Count
# 0    9806.6   7342
# 1   10002.8   7198
# 2    9806.6   7342
# 3    9806.6   7342
# 4    9806.6   7342
# 5    9806.6   7342
# 6    9806.6   7342
# 7    9806.6   7342
# 8    9806.6   7342
# 9    9806.6   7342
# 10   9806.6   7342
# 11   9806.6   7342
# 12   9806.6   7342
# 13   9806.6   7342
# 14   9806.6   7342
# 15  10002.8   7198
# 16   9806.6   7342
# 17  10002.8   7198
# 18   9806.6   7342
# 19   9806.6   7342
#
# Mean of all rows:
# Freq     9844.634579
# Count    7314.084523
# dtype: float64
#
# Median of all rows:
# Freq     9806.6
# Count    7342.0
# dtype: float64
#
# Average per 10 rows [mean_table]
#       Freq   Count
# 0  9826.22  7327.6
# 1  9845.84  7313.2
# 2  9826.22  7327.6
# 3  9865.46  7298.8
# 4  9826.09  7327.7
# File Name: 15cm.csv
# Content:
#       Freq  Count
# 0   9806.6   7342
# 1   9806.6   7342
# 2   9806.6   7342
# 3   9806.6   7342
# 4   9618.0   7486
# 5   9806.6   7342
# 6   9618.0   7486
# 7   9806.6   7342
# 8   9806.6   7342
# 9   9806.6   7342
# 10  9806.6   7342
# 11  9806.6   7342
# 12  9618.0   7486
# 13  9806.6   7342
# 14  9806.6   7342
# 15  9806.6   7342
# 16  9806.6   7342
# 17  9806.6   7342
# 18  9806.6   7342
# 19  9806.6   7342
#
# Mean of all rows:
# Freq     9759.270279
# Count    7378.136039
# dtype: float64
#
# Median of all rows:
# Freq     9806.6
# Count    7342.0
# dtype: float64
#
# Average per 10 rows [mean_table]
#       Freq   Count
# 0  9768.88  7370.8
# 1  9787.74  7356.4
# 2  9750.02  7385.2
# 3  9787.74  7356.4
# 4  9750.02  7385.2
# File Name: 18cm.csv
# Content:
#       Freq  Count
# 0   9618.0   7486
# 1   9806.6   7342
# 2   9806.6   7342
# 3   9806.6   7342
# 4   9618.0   7486
# 5   9618.0   7486
# 6   9618.0   7486
# 7   9618.0   7486
# 8   9806.6   7342
# 9   9806.6   7342
# 10  9806.6   7342
# 11  9806.6   7342
# 12  9618.0   7486
# 13  9618.0   7486
# 14  9618.0   7486
# 15  9618.0   7486
# 16  9806.6   7342
# 17  9806.6   7342
# 18  9806.6   7342
# 19  9618.0   7486
#
# Mean of all rows:
# Freq     9710.294664
# Count    7415.529337
# dtype: float64
#
# Median of all rows:
# Freq     9619.2
# Count    7485.0
# dtype: float64
#
# Average per 10 rows [mean_table]
#       Freq   Count
# 0  9712.30  7414.0
# 1  9712.30  7414.0
# 2  9712.30  7414.0
# 3  9693.44  7428.4
# 4  9731.16  7399.6
# File Name: 21cm.csv
# Content:
#       Freq   Count
# 0   9618.0  7486.0
# 1   9618.0  7486.0
# 2   9806.6  7342.0
# 3   9806.6  7342.0
# 4   9618.0  7486.0
# 5   9618.0  7486.0
# 6   9806.6  7342.0
# 7   9806.6  7342.0
# 8   9618.0  7486.0
# 9   9618.0  7486.0
# 10  9806.6  7342.0
# 11  9618.0  7486.0
# 12  9618.0  7486.0
# 13  9618.0  7486.0
# 14  9806.6  7342.0
# 15  9618.0  7486.0
# 16  9618.0  7486.0
# 17  9806.6  7342.0
# 18  9806.6  7342.0
# 19  9618.0  7486.0
#
# Mean of all rows:
# Freq     9693.740344
# Count    7428.189022
# dtype: float64
#
# Median of all rows:
# Freq     9618.0
# Count    7486.0
# dtype: float64
#
# Average per 10 rows [mean_table]
#       Freq   Count
# 0  9693.44  7428.4
# 1  9693.44  7428.4
# 2  9693.44  7428.4
# 3  9693.44  7428.4
# 4  9712.30  7414.0
# File Name: 23cm.csv
# Content:
#       Freq  Count
# 0   9618.0   7486
# 1   9806.6   7342
# 2   9618.0   7486
# 3   9618.0   7486
# 4   9618.0   7486
# 5   9806.6   7342
# 6   9618.0   7486
# 7   9806.6   7342
# 8   9618.0   7486
# 9   9618.0   7486
# 10  9618.0   7486
# 11  9806.6   7342
# 12  9618.0   7486
# 13  9806.6   7342
# 14  9618.0   7486
# 15  9618.0   7486
# 16  9618.0   7486
# 17  9806.6   7342
# 18  9618.0   7486
# 19  9618.0   7486
#
# Mean of all rows:
# Freq     9671.925037
# Count    7444.825159
# dtype: float64
#
# Median of all rows:
# Freq     9618.0
# Count    7486.0
# dtype: float64
#
# Average per 10 rows [mean_table]
#       Freq   Count
# 0  9674.58  7442.8
# 1  9674.58  7442.8
# 2  9655.72  7457.2
# 3  9655.58  7457.3
# 4  9674.58  7442.8
# File Name: 3cm.csv
# Content:
#        Freq  Count
# 0   10207.0   7054
# 1   10002.8   7198
# 2   10002.8   7198
# 3   10002.8   7198
# 4   10002.8   7198
# 5   10002.8   7198
# 6   10001.4   7199
# 7   10002.8   7198
# 8   10002.8   7198
# 9   10002.8   7198
# 10  10002.8   7198
# 11  10205.5   7055
# 12  10207.0   7054
# 13  10207.0   7054
# 14  10207.0   7054
# 15  10207.0   7054
# 16  10207.0   7054
# 17  10207.0   7054
# 18  10207.0   7054
# 19  10207.0   7054
#
# Mean of all rows:
# Freq     10080.431552
# Count     7142.405580
# dtype: float64
#
# Median of all rows:
# Freq     10002.8
# Count     7198.0
# dtype: float64
#
# Average per 10 rows [mean_table]
#        Freq   Count
# 0  10023.08  7183.7
# 1  10186.43  7068.5
# 2  10084.48  7140.4
# 3  10064.06  7154.8
# 4  10207.00  7054.0
# File Name: 4,5cm.csv
# Content:
#        Freq  Count
# 0   10207.0   7054
# 1   10207.0   7054
# 2   10419.7   6910
# 3   10419.7   6910
# 4   10207.0   7054
# 5   10207.0   7054
# 6   10207.0   7054
# 7   10419.7   6910
# 8   10207.0   7054
# 9   10205.5   7055
# 10  10207.0   7054
# 11  10419.7   6910
# 12  10418.2   6911
# 13  10419.7   6910
# 14  10207.0   7054
# 15  10207.0   7054
# 16  10207.0   7054
# 17  10419.7   6910
# 18  10419.7   6910
# 19  10205.5   7055
#
# Mean of all rows:
# Freq     10272.615506
# Count     7009.596618
# dtype: float64
#
# Median of all rows:
# Freq     10207.0
# Count     7054.0
# dtype: float64
#
# Average per 10 rows [mean_table]
#        Freq   Count
# 0  10270.66  7010.9
# 1  10313.05  6982.2
# 2  10291.93  6996.5
# 3  10291.93  6996.5
# 4  10292.08  6996.4
# File Name: 6cm.csv
# Content:
#        Freq  Count
# 0   10002.8   7198
# 1   10002.8   7198
# 2   10002.8   7198
# 3    9806.6   7342
# 4   10002.8   7198
# 5    9806.6   7342
# 6   10002.8   7198
# 7   10002.8   7198
# 8    9806.6   7342
# 9   10002.8   7198
# 10   9806.6   7342
# 11  10002.8   7198
# 12  10002.8   7198
# 13  10002.8   7198
# 14  10001.4   7199
# 15   9806.6   7342
# 16  10002.8   7198
# 17   9806.6   7342
# 18  10002.8   7198
# 19  10002.8   7198
#
# Mean of all rows:
# Freq     9979.728938
# Count    7215.311214
# dtype: float64
#
# Median of all rows:
# Freq     10002.8
# Count     7198.0
# dtype: float64
#
# Average per 10 rows [mean_table]
#       Freq   Count
# 0  9943.94  7241.2
# 1  9943.80  7241.3
# 2  9963.42  7226.9
# 3  9943.80  7241.3
# 4  9943.80  7241.3
# File Name: 9cm.csv
# Content:
#        Freq   Count
# 0    9806.6  7342.0
# 1   10002.8  7198.0
# 2   10002.8  7198.0
# 3   10001.4  7199.0
# 4    9806.6  7342.0
# 5   10002.8  7198.0
# 6   10002.8  7198.0
# 7   10002.8  7198.0
# 8   10002.8  7198.0
# 9   10002.8  7198.0
# 10  10002.8  7198.0
# 11  10002.8  7198.0
# 12  10002.8  7198.0
# 13  10002.8  7198.0
# 14   9806.6  7342.0
# 15  10002.8  7198.0
# 16   9806.6  7342.0
# 17  10002.8  7198.0
# 18  10002.8  7198.0
# 19  10002.8  7198.0
#
# Mean of all rows:
# Freq     9944.206411
# Count    7239.395989
# dtype: float64
#
# Median of all rows:
# Freq     10002.8
# Count     7198.0
# dtype: float64
#
# Average per 10 rows [mean_table]
#       Freq   Count
# 0  9963.42  7226.9
# 1  9963.56  7226.8
# 2  9963.56  7226.8
# 3  9924.32  7255.6
# 4  9924.32  7255.6
